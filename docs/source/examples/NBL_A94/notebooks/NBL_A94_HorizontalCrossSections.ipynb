# %% [markdown]
# # NBL Andren et al. (1994): Horizontal Cross-Sectional Views

# %% [markdown]
# *Last updated: May 2026*

# %% [markdown]
# **Case Description:** This notebook shows horizontal (x-y plane) cross-sections of the longitudinal velocity field from the modified **Andren et al. (1994)** neutral boundary layer case. Cross-sections are extracted at four height levels near 50 m, 100 m, 250 m, and 500 m. The 3D fields are sampled near the end of the simulation (~80 h).

# %% [markdown]
# **Load the necessary packages**

# %%
import os
import re
import glob
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Input & Output Directories**

# %%
from pathlib import Path

# Base directory (JAXALFA0.1/)
def find_repo_root(start=None):
    path = Path(start or ('__file__' in globals() and __file__) or Path.cwd()).resolve()
    for candidate in (path, *path.parents):
        if (candidate / 'examples').is_dir() and (candidate / 'docs').is_dir():
            return candidate
    raise FileNotFoundError('Could not locate JAXALFA0.1 repository root')

BaseDir = find_repo_root()

RunDir1 = BaseDir / 'examples/NBL_A94/runs/64x64x64_LASDD_SM_SP'
RunDir2 = BaseDir / 'examples/NBL_A94/runs/128x128x128_LASDD_SM_SP'
RunDir3 = BaseDir / 'examples/NBL_A94/runs/256x256x256_LASDD_SM_SP'

OutputDir1 = RunDir1 / 'output'
OutputDir2 = RunDir2 / 'output'
OutputDir3 = RunDir3 / 'output'

# %% [markdown]
# **Load 3D fields from T = 80 h**

# %%
def load_run_3d(run_dir):
    cfg = {}
    exec((run_dir / 'Config.py').read_text(), cfg)
    T_snapshot = float(cfg['SimTime'])  # use end-of-run snapshot
    iteration = int(T_snapshot / float(cfg['dt']))
    field_path = run_dir / 'output' / f'ALFA_3DFields_Iteration_{iteration}.npz'
    if field_path.exists():
        data = np.load(field_path)
        return data['u'], cfg
    print(f'Missing {field_path}; plotting NaN placeholders for this run.')
    return np.full((int(cfg['nx']), int(cfg['ny']), int(cfg['nz'])), np.nan), cfg

u3D_1, cfg_1 = load_run_3d(RunDir1)
u3D_2, cfg_2 = load_run_3d(RunDir2)
u3D_3, cfg_3 = load_run_3d(RunDir3)

# %% [markdown]
# **Input Information from the Config File**

# %%
# Common settings across the selected simulations
l_x = float(cfg_1['l_x'])
l_y = float(cfg_1['l_y'])
l_z = float(cfg_1['l_z'])
SimTime = float(cfg_1['SimTime'])
OutputInterval = float(cfg_1['OutputInterval_sec'])

# %%
for _i, _cfg in enumerate([cfg_1, cfg_2, cfg_3], start=1):
    globals()[f'nx_{_i}'] = int(_cfg['nx'])
    globals()[f'ny_{_i}'] = int(_cfg['ny'])
    globals()[f'nz_{_i}'] = int(_cfg['nz'])
    globals()[f'dx_{_i}'] = float(_cfg['l_x']) / int(_cfg['nx'])
    globals()[f'dy_{_i}'] = float(_cfg['l_y']) / int(_cfg['ny'])
    globals()[f'dz_{_i}'] = float(_cfg['l_z']) / (int(_cfg['nz']) - 1)
    globals()[f'x_axis_{_i}'] = globals()[f'dx_{_i}'] * np.arange(globals()[f'nx_{_i}'])
    globals()[f'y_axis_{_i}'] = globals()[f'dy_{_i}'] * np.arange(globals()[f'ny_{_i}'])

# %% [markdown]
# **Derived Variables**

# %%
# Half levels for u, v, TH variables
z_u_1 = np.array([(k + 0.5) * l_z / (nz_1 - 1) for k in range(nz_1)])
z_u_2 = np.array([(k + 0.5) * l_z / (nz_2 - 1) for k in range(nz_2)])
z_u_3 = np.array([(k + 0.5) * l_z / (nz_3 - 1) for k in range(nz_3)])

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.size": 14,
    "axes.labelsize": 16,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12
})

# %% [markdown]
# **Plot horizontal cross-section of longitudinal velocity fields: 64x64x64 run**

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9), constrained_layout=True)
axes = axes.flatten()

# Target heights (m) — nearest grid level selected automatically
target_heights = [50, 100, 250, 500]
k_levels = [int(np.argmin(np.abs(z_u_1 - h))) for h in target_heights]

# Colorbar range
vmin = 3
vmax = 6

for i, k in enumerate(k_levels):
    im = axes[i].pcolor(x_axis_1, y_axis_1, u3D_1[:,:,k].T, cmap='inferno',
                        vmin=vmin, vmax=vmax)
    axes[i].set_title(f'Z = {z_u_1[k]:.0f} m', fontsize=12)
    axes[i].set_xlabel('X (m)')
    axes[i].set_ylabel('Y (m)')
    axes[i].set_aspect('auto')

fig.colorbar(im, ax=axes.tolist(), label='Longitudinal Velocity (m/s)', shrink=0.6)
fig.suptitle('Simulation: 64x64x64', fontsize=16)
plt.show()

# %% [markdown]
# **Plot horizontal cross-section of longitudinal velocity fields: 128x128x128 run**

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9), constrained_layout=True)
axes = axes.flatten()

# Target heights (m) — nearest grid level selected automatically
target_heights = [50, 100, 250, 500]
k_levels = [int(np.argmin(np.abs(z_u_2 - h))) for h in target_heights]

# Colorbar range
vmin = 3
vmax = 6

for i, k in enumerate(k_levels):
    im = axes[i].pcolor(x_axis_2, y_axis_2, u3D_2[:,:,k].T, cmap='inferno',
                        vmin=vmin, vmax=vmax)
    axes[i].set_title(f'Z = {z_u_2[k]:.0f} m', fontsize=12)
    axes[i].set_xlabel('X (m)')
    axes[i].set_ylabel('Y (m)')
    axes[i].set_aspect('auto')

fig.colorbar(im, ax=axes.tolist(), label='Longitudinal Velocity (m/s)', shrink=0.6)
fig.suptitle('Simulation: 128x128x128', fontsize=16)
plt.show()

# %% [markdown]
# **Plot horizontal cross-section of longitudinal velocity fields: 256x256x256 run**

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9), constrained_layout=True)
axes = axes.flatten()

# Target heights (m) — nearest grid level selected automatically
target_heights = [50, 100, 250, 500]
k_levels = [int(np.argmin(np.abs(z_u_3 - h))) for h in target_heights]

# Colorbar range
vmin = 3
vmax = 6

for i, k in enumerate(k_levels):
    im = axes[i].pcolor(x_axis_3, y_axis_3, u3D_3[:,:,k].T, cmap='inferno',
                        vmin=vmin, vmax=vmax)
    axes[i].set_title(f'Z = {z_u_3[k]:.0f} m', fontsize=12)
    axes[i].set_xlabel('X (m)')
    axes[i].set_ylabel('Y (m)')
    axes[i].set_aspect('auto')

fig.colorbar(im, ax=axes.tolist(), label='Longitudinal Velocity (m/s)', shrink=0.6)
fig.suptitle('Simulation: 256x256x256', fontsize=16)
plt.show()
