# %% [markdown]
# # Horizontal Cross-Sectional Views

# %% [markdown]
# **Last Updated: May 1, 2026**

# %% [markdown]
# **Case Description:** This notebook shows horizontal (x-y plane) cross-sections of the longitudinal velocity field from the modified **Andren et al. (1994)** neutral boundary layer case. Cross-sections are extracted at four height levels near 100 m, 250 m, 500 m, and 1000 m. The 3D fields are sampled near the end of the simulation (~27 h). See the **NBL_A94_Profiles** notebook for temporally averaged vertical profiles and full case parameters.

# %% [markdown]
# **Load the necessary packages**

# %%
import os
import re
import glob
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Input & Output Directories**

# %%
from pathlib import Path

# Base directory (JAXALFA0.1/) — 5 levels above this notebook
BaseDir = Path(__file__).parents[4] if '__file__' in dir() else Path.cwd().parents[4]

# 80x80x80 run
OutputDir1 = BaseDir / 'examples/NBL_A94/runs/80x80x80/output'

# 128x128x128 run
OutputDir2 = BaseDir / 'examples/NBL_A94/runs/128x128x128/output'

# %% [markdown]
# **Load 3D fields from T = 27 h**

# %%
T_snapshot = 27 * 3600  # unit: sec

# 80x80x80 run (dt = 2 sec)
dt_1 = 2
iter_1 = int(T_snapshot / dt_1)
File3D_1 = np.load(OutputDir1 / f'ALFA_3DFields_Iteration_{iter_1}.npz')
u3D_1 = File3D_1['u']

# 128x128x128 run (dt = 1 sec)
# dt_2 = 1
# iter_2 = int(T_snapshot / dt_2)
# File3D_2 = np.load(OutputDir2 / f'ALFA_3DFields_Iteration_{iter_2}.npz')
# u3D_2 = File3D_2['u']

# %% [markdown]
# **Input Information from the Config File**

# %%
# Common settings across the simulations
l_x = 4000 # domain length (m)
l_y = 4000 # domain width (m)
l_z = 4000 # domain height (m)
SimTime = 100000  # total simulation time (sec)
OutputInterval = 60 # frequency of output (sec)

# %%
# Simulation 1
nx_1 = 80 # number of grid points in x direction
ny_1 = 80 # number of grid points in y direction
nz_1 = 80 # number of grid points in z direction
dx_1 = l_x / nx_1
dy_1 = l_y / ny_1
dz_1 = l_z / (nz_1 - 1)
x_axis_1 = dx_1 * np.arange(nx_1)
y_axis_1 = dy_1 * np.arange(ny_1)

# Simulation 2
nx_2 = 128 # number of grid points in x direction
ny_2 = 128 # number of grid points in y direction
nz_2 = 128 # number of grid points in z direction
dx_2 = l_x / nx_2
dy_2 = l_y / ny_2
dz_2 = l_z / (nz_2 - 1)
x_axis_2 = dx_2 * np.arange(nx_2)
y_axis_2 = dy_2 * np.arange(ny_2)

# %% [markdown]
# **Derived Variables**

# %%
# Half levels for u, v, TH variables
z_u_1 = np.array([(k + 0.5) * l_z / (nz_1 - 1) for k in range(nz_1)])
z_u_2 = np.array([(k + 0.5) * l_z / (nz_2 - 1) for k in range(nz_2)])

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.size": 14,
    "axes.labelsize": 16,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12
})

# %% [markdown]
# **Plot horizontal cross-section of longitudinal velocity fields: 80x80x80 run**

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9), constrained_layout=True)
axes = axes.flatten()

# Target heights (m) — nearest grid level selected automatically
target_heights = [100, 250, 500, 1000]
k_levels = [int(np.argmin(np.abs(z_u_1 - h))) for h in target_heights]

# Colorbar range
vmin = 3
vmax = 6

for i, k in enumerate(k_levels):
    im = axes[i].pcolor(x_axis_1, y_axis_1, u3D_1[:,:,k].T, cmap='inferno',
                        vmin=vmin, vmax=vmax)
    axes[i].set_title(f'Z = {z_u_1[k]:.0f} m', fontsize=12)
    axes[i].set_xlabel('X (m)')
    axes[i].set_ylabel('Y (m)')
    axes[i].set_aspect('auto')

fig.colorbar(im, ax=axes.tolist(), label='Longitudinal Velocity (m/s)', shrink=0.6)
fig.suptitle('Simulation: 80x80x80', fontsize=16)
plt.show()

# %% [markdown]
# **Plot horizontal cross-section of longitudinal velocity fields: 128x128x128 run**

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9), constrained_layout=True)
axes = axes.flatten()

# Target heights (m) — nearest grid level selected automatically
target_heights = [100, 250, 500, 1000]
k_levels = [int(np.argmin(np.abs(z_u_2 - h))) for h in target_heights]

# Colorbar range
vmin = 3
vmax = 6

for i, k in enumerate(k_levels):
    im = axes[i].pcolor(x_axis_2, y_axis_2, u3D_2[:,:,k].T, cmap='inferno',
                        vmin=vmin, vmax=vmax)
    axes[i].set_title(f'Z = {z_u_2[k]:.0f} m', fontsize=12)
    axes[i].set_xlabel('X (m)')
    axes[i].set_ylabel('Y (m)')
    axes[i].set_aspect('auto')

fig.colorbar(im, ax=axes.tolist(), label='Longitudinal Velocity (m/s)', shrink=0.6)
fig.suptitle('Simulation: 128x128x128', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 13
#      10 vmax = 6
#      12 for i, k in enumerate(k_levels):
# ---> 13     im = axes[i].pcolor(x_axis_2, y_axis_2, u3D_2[:,:,k].T, cmap='inferno',
#      14                         vmin=vmin, vmax=vmax)
#      15     axes[i].set_title(f'Z = {z_u_2[k]:.0f} m', fontsize=12)
#      16     axes[i].set_xlabel('X (m)')
#
# NameError: name 'u3D_2' is not defined
